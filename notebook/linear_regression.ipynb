# %% [markdown]
# # Linear Regression

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from pprint import pprint
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Exploration

# %%
data_boston_housing = datasets.fetch_california_housing()
data_boston_housing.data.shape

description = data_boston_housing.DESCR.split('\n')
description = list(filter(lambda d: len(d) > 0, description)) # we only want non-empty strings in the list
pprint(description)
print(data_boston_housing.data.shape)
print('target_names', data_boston_housing.target_names)
print('feature_names', data_boston_housing.feature_names)
print('first_row', data_boston_housing.data[0])

x = data_boston_housing.data
y  = data_boston_housing.target

print(x, y)
# Out:
# ['.. _california_housing_dataset:',
#  'California Housing dataset',
#  '--------------------------',
#  '**Data Set Characteristics:**',
#  '    :Number of Instances: 20640',
#  '    :Number of Attributes: 8 numeric, predictive attributes and the target',
#  '    :Attribute Information:',
#  '        - MedInc        median income in block group',
#  '        - HouseAge      median house age in block group',
#  '        - AveRooms      average number of rooms per household',
#  '        - AveBedrms     average number of bedrooms per household',
#  '        - Population    block group population',
#  '        - AveOccup      average number of household members',
#  '        - Latitude      block group latitude',
#  '        - Longitude     block group longitude',
#  '    :Missing Attribute Values: None',
#  'This dataset was obtained from the StatLib repository.',
#  'https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html',
#  'The target variable is the median house value for California districts,',
#  'expressed in hundreds of thousands of dollars ($100,000).',
#  'This dataset was derived from the 1990 U.S. census, using one row per census',
#  'block group. A block group is the smallest geographical unit for which the '
#  'U.S.',
#  'Census Bureau publishes sample data (a block group typically has a '
#  'population',
#  'of 600 to 3,000 people).',
#  'An household is a group of people residing within a home. Since the average',
#  'number of rooms and bedrooms in this dataset are provided per household, '
#  'these',
#  'columns may take surpinsingly large values for block groups with few '
#  'households',
#  'and many empty houses, such as vacation resorts.',
#  'It can be downloaded/loaded using the',
#  ':func:`sklearn.datasets.fetch_california_housing` function.',
#  '.. topic:: References',
#  '    - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,',
#  '      Statistics and Probability Letters, 33 (1997) 291-297']
# (20640, 8)
# target_names ['MedHouseVal']
# feature_names ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# first_row [   8.3252       41.            6.98412698    1.02380952  322.
#     2.55555556   37.88       -122.23      ]
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]] [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %% [markdown]
# Let's quickly visualize the features.

# %%
for i in range(x.shape[1]):
    plt.scatter(x[:, i], y)
    plt.show()

# %% [markdown]
# ## Setup and Train Model

# %% [markdown]
# $$
# f(x; w,b) = w^T x + b
# $$
#
# Let's try to fit a vanilla linear regression model

# %%
lr = LinearRegression(
    fit_intercept=True, # since our data is not centered, we will probably need to have an intercept
    normalize=False, # not normalizing on the first try
    positive=False, # not forcing coefficients to be positive
    copy_X=True, # to ensure original input data is not overwritten
)
fitted_lr = lr.fit(x, y)
# Out:
# /Users/henry/Git/ml-algorithms/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(

# %% [markdown]
# We want to check the $R^2$ coefficient of determination of the prediction, where $R^2 = 1 - \frac{\text{residual sum of squares} }{\text{total sum of squares}}$

# %%
r_squared = fitted_lr.score(x, y)
print(r_squared)
# Out:
# 0.606232685199805

# %% [markdown]
# Let's try to predict using the learned model coefficients.

# %%
from random import randint


for i in range(3):
    idx = randint(0, len(x))
    y_pred = fitted_lr.predict(x[idx].reshape(1, -1))
    print(f'Prediction {i}')
    pprint(list(zip(data_boston_housing.feature_names, x[idx])))
    print(f'y={y[idx]}, y_pred={y_pred[0]}')
# Out:
# Prediction 0
# [('MedInc', 6.2236),
#  ('HouseAge', 32.0),
#  ('AveRooms', 6.488789237668161),
#  ('AveBedrms', 0.9573991031390134),
#  ('Population', 1151.0),
#  ('AveOccup', 2.5807174887892375),
#  ('Latitude', 34.16),
#  ('Longitude', -117.27)]
# y=1.597, y_pred=2.548004331638083
# Prediction 1
# [('MedInc', 1.59),
#  ('HouseAge', 49.0),
#  ('AveRooms', 4.39186295503212),
#  ('AveBedrms', 1.0706638115631693),
#  ('Population', 1525.0),
#  ('AveOccup', 3.2655246252676657),
#  ('Latitude', 37.63),
#  ('Longitude', -121.0)]
# y=0.809, y_pred=1.1377552959671107
# Prediction 2
# [('MedInc', 4.2383),
#  ('HouseAge', 18.0),
#  ('AveRooms', 7.572438162544169),
#  ('AveBedrms', 1.0565371024734982),
#  ('Population', 828.0),
#  ('AveOccup', 2.9257950530035335),
#  ('Latitude', 33.17),
#  ('Longitude', -117.32)]
# y=2.39, y_pred=1.9353919961917896

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# Let's check the coefficients of the linear regression model.
# Each coefficient means the feature importance $x$ with respect to the independent variable $y$

# %%
pprint(list(zip(data_boston_housing.feature_names, fitted_lr.coef_)))
# Out:
# [('MedInc', 0.4366932931343245),
#  ('HouseAge', 0.009435778033237972),
#  ('AveRooms', -0.10732204139090447),
#  ('AveBedrms', 0.645065693519812),
#  ('Population', -3.976389421211576e-06),
#  ('AveOccup', -0.003786542654971),
#  ('Latitude', -0.42131437752714385),
#  ('Longitude', -0.43451375467477743)]

# %% [markdown]
# ## Second Attempt (Excluding "Population" Feature)

# %% [markdown]
# We can see the "population" feature isn't that important.
# Let's see how the prediction looks like after excluding it.

# %%
lr = LinearRegression(
    fit_intercept=True, # since our data is not centered, we will probably need to have an intercept
    normalize=False, # not normalizing on the first try
    positive=False, # not forcing coefficients to be positive
    copy_X=True, # to ensure original input data is not overwritten
)
x_without_population = pd.DataFrame(x, columns=data_boston_housing.feature_names)
x_without_population.drop('Population', axis=1, inplace=True)
print(x_without_population.head(1))
fitted_lr_without_population = lr.fit(x_without_population, y)
r_squared = fitted_lr_without_population.score(x_without_population, y)
print(r_squared)

y_hat = fitted_lr_without_population.predict(x_without_population)
errors = y_hat - y
plt.xlabel('error')
plt.ylabel('y')
plt.scatter(errors, y)
plt.show()
print('avg errors', errors.mean())
pprint(list(zip(data_boston_housing.feature_names, fitted_lr_without_population.coef_)))
# Out:
# /Users/henry/Git/ml-algorithms/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
#    MedInc  HouseAge  AveRooms  AveBedrms  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127    1.02381  2.555556     37.88    -122.23
# 0.6062193051855559
# avg errors 5.2794977691942325e-15
# [('MedInc', 0.43675974780362403),
#  ('HouseAge', 0.009555467799549792),
#  ('AveRooms', -0.10713405779069167),
#  ('AveBedrms', 0.6449021952418097),
#  ('Population', -0.0038193279128491972),
#  ('AveOccup', -0.42069941655554943),
#  ('Latitude', -0.4340421535595173)]

# %% [markdown]
# There are 4 assumptions for linear regression model.
# 1. Linear relationship between independent variable ($x$) and target variable ($y$)
# 2. **Additivity** means that the effect of changes in one of the features on the target variable does not depend on values of other features.
# 3. Features should not be correlated (no **collinearity**) since it can be difficult to separate out the individual effects of collinear features on the target variable.
# 4. Independently and identically normally distributed (iid).
#   - Otherwise some features will have more influence on the target variable than to others.
#   - Error is constant along the values of the dependent variable - [[homoscedasticity]]. For example, in case of time series, seasonal patterns can increase errors in seasons with higher activity. The below example shows non-constant errors, with more errors on the higher end than the lower end. If that's the case, you probably don't want to do linear regression on this dataset yet. You may want to do some work on your input data: maybe you have some variables to add or remove. If this assumption still cannot be achieved, you can switch to [[#Weighted Linear Regression]] model.

# %% [markdown]
# Let's quickly check the correlation between features.
# In particular, we will be using the Pearson's correlation coefficient.
# ```
# E[(X[:, i] - mean(X[:, i])) * (y - mean(y))] / (std(X[:, i]) * std(y))
# ```

# %%
pd.DataFrame(x, columns=data_boston_housing.feature_names)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
from sklearn.feature_selection import r_regression

x_corr_matrix = pd.DataFrame(x, columns=data_boston_housing.feature_names).corr()
x_corr_matrix

fig, ax = plt.subplots(1,1)
img = ax.imshow(x_corr_matrix, cmap='autumn')

ax.set_xticklabels(data_boston_housing.feature_names)
ax.set_yticklabels(data_boston_housing.feature_names)

fig.set_size_inches(10, 10)
fig.colorbar(img)
# Out:
# /var/folders/m2/8936fkv54pxbvdyy2wq30dqh0000gn/T/ipykernel_9870/1261732307.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data_boston_housing.feature_names)
# /var/folders/m2/8936fkv54pxbvdyy2wq30dqh0000gn/T/ipykernel_9870/1261732307.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(data_boston_housing.feature_names)

# %% [markdown]
# Next, let's check the distribution of errors with respect to Y

# %%
y_hat = fitted_lr.predict(x)
errors = abs(y_hat - y)
plt.xlabel('error')
plt.ylabel('y')
plt.scatter(errors, y)
plt.show()
print('avg errors', errors.mean())
rsme = np.sqrt(((y_hat - y)**2).mean())
print('RMSE', rsme)
# Out:
# avg errors 0.5311643817546476
# RMSE 0.7241001216576387

# %% [markdown]
# ## Weighted Linear Regression

# %% [markdown]
# In this variant of linear regression, we will use the variance of observations as additional information to guide our regression prediction. More specifically:
#
# $$
# \hat{w} = (X^T C^{-1} X)^{-1} X^T C^{-1} y
# $$
#
# where $w$ is the weights of observations, and $c$ is the covariance of observations.

# %%
x_sampled = x[:3000]
y_sampled = y[:3000]
residuals = y_sampled - fitted_lr.predict(x_sampled)
covar = np.diag(residuals ** 2)
print(covar.shape)

weights = np.linalg.inv(x_sampled.T @ np.linalg.inv(covar) @ x_sampled) @ (x_sampled.T @ np.linalg.inv(covar) @ y_sampled)
print(weights.shape)

y_hat_sampled = x_sampled @ weights
rsme = np.sqrt(((y_hat_sampled - y_sampled)**2).mean())
print('RMSE', rsme)
# Out:
# (3000, 3000)
# (8,)
# RMSE 0.8976166598624791

# %% [markdown]
# ## Next Steps

# %% [markdown]
# To motivate for non-linear models, we will use a vanilla parametric non-linear model to train the same dataset

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler

mlp_r = MLPRegressor(
    hidden_layer_sizes=(128, 128, 64, 32, 16, 8),
    activation='relu',
    solver='adam',
    alpha=1e-4, # l2 regularization strength
    learning_rate='adaptive',
    learning_rate_init=1e-5,
    shuffle=True,
    max_iter=1000,
    verbose=True,
)

sc = StandardScaler()
scaler = sc.fit(x)
x_scaled = scaler.transform(x)

fitted_mlp_r = mlp_r.fit(x_scaled, y)
# Out:
# Iteration 1, loss = 2.63498046
# Iteration 2, loss = 2.48354366
# Iteration 3, loss = 2.26234536
# Iteration 4, loss = 2.01126879
# Iteration 5, loss = 1.76796602
# Iteration 6, loss = 1.53584960
# Iteration 7, loss = 1.30358468
# Iteration 8, loss = 1.09151610
# Iteration 9, loss = 0.91793341
# Iteration 10, loss = 0.79217216
# Iteration 11, loss = 0.70146106
# Iteration 12, loss = 0.63557384
# Iteration 13, loss = 0.58303860
# Iteration 14, loss = 0.54039062
# Iteration 15, loss = 0.50386637
# Iteration 16, loss = 0.47238639
# Iteration 17, loss = 0.44506477
# Iteration 18, loss = 0.42153649
# Iteration 19, loss = 0.40080118
# Iteration 20, loss = 0.38263196
# Iteration 21, loss = 0.36661078
# Iteration 22, loss = 0.35269414
# Iteration 23, loss = 0.34047312
# Iteration 24, loss = 0.32972143
# Iteration 25, loss = 0.32033137
# Iteration 26, loss = 0.31211429
# Iteration 27, loss = 0.30490652
# Iteration 28, loss = 0.29864268
# Iteration 29, loss = 0.29303740
# Iteration 30, loss = 0.28774174
# Iteration 31, loss = 0.28287551
# Iteration 32, loss = 0.27833906
# Iteration 33, loss = 0.27399144
# Iteration 34, loss = 0.26994961
# Iteration 35, loss = 0.26615650
# Iteration 36, loss = 0.26262447
# Iteration 37, loss = 0.25942622
# Iteration 38, loss = 0.25634349
# Iteration 39, loss = 0.25342316
# Iteration 40, loss = 0.25055598
# Iteration 41, loss = 0.24790051
# Iteration 42, loss = 0.24528370
# Iteration 43, loss = 0.24287269
# Iteration 44, loss = 0.24055389
# Iteration 45, loss = 0.23826069
# Iteration 46, loss = 0.23607888
# Iteration 47, loss = 0.23401471
# Iteration 48, loss = 0.23200890
# Iteration 49, loss = 0.23017939
# Iteration 50, loss = 0.22825611
# Iteration 51, loss = 0.22646021
# Iteration 52, loss = 0.22472915
# Iteration 53, loss = 0.22304634
# Iteration 54, loss = 0.22138734
# Iteration 55, loss = 0.21977689
# Iteration 56, loss = 0.21826817
# Iteration 57, loss = 0.21669298
# Iteration 58, loss = 0.21528256
# Iteration 59, loss = 0.21387641
# Iteration 60, loss = 0.21255925
# Iteration 61, loss = 0.21129805
# Iteration 62, loss = 0.21009579
# Iteration 63, loss = 0.20882423
# Iteration 64, loss = 0.20771763
# Iteration 65, loss = 0.20654727
# Iteration 66, loss = 0.20541400
# Iteration 67, loss = 0.20428588
# Iteration 68, loss = 0.20321760
# Iteration 69, loss = 0.20221251
# Iteration 70, loss = 0.20116791
# Iteration 71, loss = 0.20019573
# Iteration 72, loss = 0.19923857
# Iteration 73, loss = 0.19830040
# Iteration 74, loss = 0.19737909
# Iteration 75, loss = 0.19642305
# Iteration 76, loss = 0.19555815
# Iteration 77, loss = 0.19474212
# Iteration 78, loss = 0.19385227
# Iteration 79, loss = 0.19301562
# Iteration 80, loss = 0.19221217
# Iteration 81, loss = 0.19141749
# Iteration 82, loss = 0.19067052
# Iteration 83, loss = 0.18990321
# Iteration 84, loss = 0.18918403
# Iteration 85, loss = 0.18843691
# Iteration 86, loss = 0.18781809
# Iteration 87, loss = 0.18714371
# Iteration 88, loss = 0.18642583
# Iteration 89, loss = 0.18581373
# Iteration 90, loss = 0.18516481
# Iteration 91, loss = 0.18450973
# Iteration 92, loss = 0.18395430
# Iteration 93, loss = 0.18345034
# Iteration 94, loss = 0.18277432
# Iteration 95, loss = 0.18219594
# Iteration 96, loss = 0.18163449
# Iteration 97, loss = 0.18111491
# Iteration 98, loss = 0.18058792
# Iteration 99, loss = 0.18006420
# Iteration 100, loss = 0.17957106
# Iteration 101, loss = 0.17901825
# Iteration 102, loss = 0.17850930
# Iteration 103, loss = 0.17806103
# Iteration 104, loss = 0.17758157
# Iteration 105, loss = 0.17715582
# Iteration 106, loss = 0.17659461
# Iteration 107, loss = 0.17621973
# Iteration 108, loss = 0.17581513
# Iteration 109, loss = 0.17535592
# Iteration 110, loss = 0.17489930
# Iteration 111, loss = 0.17451604
# Iteration 112, loss = 0.17414986
# Iteration 113, loss = 0.17381529
# Iteration 114, loss = 0.17336545
# Iteration 115, loss = 0.17307096
# Iteration 116, loss = 0.17264311
# Iteration 117, loss = 0.17230057
# Iteration 118, loss = 0.17188538
# Iteration 119, loss = 0.17157951
# Iteration 120, loss = 0.17115886
# Iteration 121, loss = 0.17085815
# Iteration 122, loss = 0.17044546
# Iteration 123, loss = 0.17017290
# Iteration 124, loss = 0.16982168
# Iteration 125, loss = 0.16947877
# Iteration 126, loss = 0.16917318
# Iteration 127, loss = 0.16889624
# Iteration 128, loss = 0.16846429
# Iteration 129, loss = 0.16823802
# Iteration 130, loss = 0.16790423
# Iteration 131, loss = 0.16758965
# Iteration 132, loss = 0.16728610
# Iteration 133, loss = 0.16702769
# Iteration 134, loss = 0.16674497
# Iteration 135, loss = 0.16654674
# Iteration 136, loss = 0.16615458
# Iteration 137, loss = 0.16589434
# Iteration 138, loss = 0.16557569
# Iteration 139, loss = 0.16536591
# Iteration 140, loss = 0.16506810
# Iteration 141, loss = 0.16483680
# Iteration 142, loss = 0.16452325
# Iteration 143, loss = 0.16429779
# Iteration 144, loss = 0.16406407
# Iteration 145, loss = 0.16375708
# Iteration 146, loss = 0.16346981
# Iteration 147, loss = 0.16328298
# Iteration 148, loss = 0.16305006
# Iteration 149, loss = 0.16276236
# Iteration 150, loss = 0.16255091
# Iteration 151, loss = 0.16231459
# Iteration 152, loss = 0.16206522
# Iteration 153, loss = 0.16183702
# Iteration 154, loss = 0.16164427
# Iteration 155, loss = 0.16142917
# Iteration 156, loss = 0.16133419
# Iteration 157, loss = 0.16091254
# Iteration 158, loss = 0.16072373
# Iteration 159, loss = 0.16045671
# Iteration 160, loss = 0.16029708
# Iteration 161, loss = 0.16004268
# Iteration 162, loss = 0.15988265
# Iteration 163, loss = 0.15962486
# Iteration 164, loss = 0.15944331
# Iteration 165, loss = 0.15919092
# Iteration 166, loss = 0.15895825
# Iteration 167, loss = 0.15887311
# Iteration 168, loss = 0.15859829
# Iteration 169, loss = 0.15837938
# Iteration 170, loss = 0.15821468
# Iteration 171, loss = 0.15804542
# Iteration 172, loss = 0.15783262
# Iteration 173, loss = 0.15753324
# Iteration 174, loss = 0.15738694
# Iteration 175, loss = 0.15718942
# Iteration 176, loss = 0.15707403
# Iteration 177, loss = 0.15686874
# Iteration 178, loss = 0.15667758
# Iteration 179, loss = 0.15641426
# Iteration 180, loss = 0.15630697
# Iteration 181, loss = 0.15609533
# Iteration 182, loss = 0.15596210
# Iteration 183, loss = 0.15571775
# Iteration 184, loss = 0.15553265
# Iteration 185, loss = 0.15535278
# Iteration 186, loss = 0.15527286
# Iteration 187, loss = 0.15506043
# Iteration 188, loss = 0.15488314
# Iteration 189, loss = 0.15469201
# Iteration 190, loss = 0.15467169
# Iteration 191, loss = 0.15442078
# Iteration 192, loss = 0.15426839
# Iteration 193, loss = 0.15408334
# Iteration 194, loss = 0.15387922
# Iteration 195, loss = 0.15373655
# Iteration 196, loss = 0.15369253
# Iteration 197, loss = 0.15350016
# Iteration 198, loss = 0.15331354
# Iteration 199, loss = 0.15315390
# Iteration 200, loss = 0.15297864
# Iteration 201, loss = 0.15296183
# Iteration 202, loss = 0.15273443
# Iteration 203, loss = 0.15256745
# Iteration 204, loss = 0.15246489
# Iteration 205, loss = 0.15234585
# Iteration 206, loss = 0.15207404
# Iteration 207, loss = 0.15202845
# Iteration 208, loss = 0.15187694
# Iteration 209, loss = 0.15169889
# Iteration 210, loss = 0.15153922
# Iteration 211, loss = 0.15147896
# Iteration 212, loss = 0.15142889
# Iteration 213, loss = 0.15118648
# Iteration 214, loss = 0.15101997
# Iteration 215, loss = 0.15093644
# Iteration 216, loss = 0.15070402
# Iteration 217, loss = 0.15066212
# Iteration 218, loss = 0.15048265
# Iteration 219, loss = 0.15030352
# Iteration 220, loss = 0.15022398
# Iteration 221, loss = 0.15025634
# Iteration 222, loss = 0.14998940
# Iteration 223, loss = 0.14990877
# Iteration 224, loss = 0.14969046
# Iteration 225, loss = 0.14956454
# Iteration 226, loss = 0.14949076
# Iteration 227, loss = 0.14939183
# Iteration 228, loss = 0.14915192
# Iteration 229, loss = 0.14915722
# Iteration 230, loss = 0.14898265
# Iteration 231, loss = 0.14880042
# Iteration 232, loss = 0.14881881
# Iteration 233, loss = 0.14860394
# Iteration 234, loss = 0.14847805
# Iteration 235, loss = 0.14843046
# Iteration 236, loss = 0.14825239
# Iteration 237, loss = 0.14815166
# Iteration 238, loss = 0.14802099
# Iteration 239, loss = 0.14789982
# Iteration 240, loss = 0.14777701
# Iteration 241, loss = 0.14763943
# Iteration 242, loss = 0.14749018
# Iteration 243, loss = 0.14738921
# Iteration 244, loss = 0.14736642
# Iteration 245, loss = 0.14719358
# Iteration 246, loss = 0.14715697
# Iteration 247, loss = 0.14695906
# Iteration 248, loss = 0.14677724
# Iteration 249, loss = 0.14684786
# Iteration 250, loss = 0.14662130
# Iteration 251, loss = 0.14651094
# Iteration 252, loss = 0.14641348
# Iteration 253, loss = 0.14632500
# Iteration 254, loss = 0.14622183
# Iteration 255, loss = 0.14608783
# Iteration 256, loss = 0.14590900
# Iteration 257, loss = 0.14586966
# Iteration 258, loss = 0.14584970
# Iteration 259, loss = 0.14573941
# Iteration 260, loss = 0.14554919
# Iteration 261, loss = 0.14542380
# Iteration 262, loss = 0.14534323
# Iteration 263, loss = 0.14526837
# Iteration 264, loss = 0.14513755
# Iteration 265, loss = 0.14500664
# Iteration 266, loss = 0.14493414
# Iteration 267, loss = 0.14484609
# Iteration 268, loss = 0.14479545
# Iteration 269, loss = 0.14461417
# Iteration 270, loss = 0.14454174
# Iteration 271, loss = 0.14438660
# Iteration 272, loss = 0.14438421
# Iteration 273, loss = 0.14427943
# Iteration 274, loss = 0.14419993
# Iteration 275, loss = 0.14405840
# Iteration 276, loss = 0.14395009
# Iteration 277, loss = 0.14381411
# Iteration 278, loss = 0.14371901
# Iteration 279, loss = 0.14357876
# Iteration 280, loss = 0.14355410
# Iteration 281, loss = 0.14349930
# Iteration 282, loss = 0.14341333
# Iteration 283, loss = 0.14320857
# Iteration 284, loss = 0.14319887
# Iteration 285, loss = 0.14305545
# Iteration 286, loss = 0.14296225
# Iteration 287, loss = 0.14286040
# Iteration 288, loss = 0.14284912
# Iteration 289, loss = 0.14276254
# Iteration 290, loss = 0.14260353
# Iteration 291, loss = 0.14253306
# Iteration 292, loss = 0.14254619
# Iteration 293, loss = 0.14241569
# Iteration 294, loss = 0.14226306
# Iteration 295, loss = 0.14217073
# Iteration 296, loss = 0.14215228
# Iteration 297, loss = 0.14203575
# Iteration 298, loss = 0.14189523
# Iteration 299, loss = 0.14181585
# Iteration 300, loss = 0.14179237
# Iteration 301, loss = 0.14162480
# Iteration 302, loss = 0.14158222
# Iteration 303, loss = 0.14155209
# Iteration 304, loss = 0.14150044
# Iteration 305, loss = 0.14134801
# Iteration 306, loss = 0.14122830
# Iteration 307, loss = 0.14112476
# Iteration 308, loss = 0.14116343
# Iteration 309, loss = 0.14100216
# Iteration 310, loss = 0.14101299
# Iteration 311, loss = 0.14083699
# Iteration 312, loss = 0.14077619
# Iteration 313, loss = 0.14067626
# Iteration 314, loss = 0.14062819
# Iteration 315, loss = 0.14052701
# Iteration 316, loss = 0.14044733
# Iteration 317, loss = 0.14031062
# Iteration 318, loss = 0.14025230
# Iteration 319, loss = 0.14019022
# Iteration 320, loss = 0.14023970
# Iteration 321, loss = 0.14005954
# Iteration 322, loss = 0.14012134
# Iteration 323, loss = 0.13996927
# Iteration 324, loss = 0.13978835
# Iteration 325, loss = 0.13984490
# Iteration 326, loss = 0.13970100
# Iteration 327, loss = 0.13972109
# Iteration 328, loss = 0.13956631
# Iteration 329, loss = 0.13944855
# Iteration 330, loss = 0.13941505
# Iteration 331, loss = 0.13930375
# Iteration 332, loss = 0.13925284
# Iteration 333, loss = 0.13920212
# Iteration 334, loss = 0.13907974
# Iteration 335, loss = 0.13902879
# Iteration 336, loss = 0.13903614
# Iteration 337, loss = 0.13880949
# Iteration 338, loss = 0.13883193
# Iteration 339, loss = 0.13879115
# Iteration 340, loss = 0.13884310
# Iteration 341, loss = 0.13855107
# Iteration 342, loss = 0.13850687
# Iteration 343, loss = 0.13848240
# Iteration 344, loss = 0.13838459
# Iteration 345, loss = 0.13835337
# Iteration 346, loss = 0.13833448
# Iteration 347, loss = 0.13826667
# Iteration 348, loss = 0.13822383
# Iteration 349, loss = 0.13806725
# Iteration 350, loss = 0.13797575
# Iteration 351, loss = 0.13795373
# Iteration 352, loss = 0.13792440
# Iteration 353, loss = 0.13782357
# Iteration 354, loss = 0.13771065
# Iteration 355, loss = 0.13768045
# Iteration 356, loss = 0.13759756
# Iteration 357, loss = 0.13759141
# Iteration 358, loss = 0.13746841
# Iteration 359, loss = 0.13737579
# Iteration 360, loss = 0.13725245
# Iteration 361, loss = 0.13729323
# Iteration 362, loss = 0.13721070
# Iteration 363, loss = 0.13711071
# Iteration 364, loss = 0.13707190
# Iteration 365, loss = 0.13699098
# Iteration 366, loss = 0.13694509
# Iteration 367, loss = 0.13685728
# Iteration 368, loss = 0.13684405
# Iteration 369, loss = 0.13671107
# Iteration 370, loss = 0.13671038
# Iteration 371, loss = 0.13664856
# Iteration 372, loss = 0.13651996
# Iteration 373, loss = 0.13643481
# Iteration 374, loss = 0.13637782
# Iteration 375, loss = 0.13631461
# Iteration 376, loss = 0.13631716
# Iteration 377, loss = 0.13621562
# Iteration 378, loss = 0.13612221
# Iteration 379, loss = 0.13607496
# Iteration 380, loss = 0.13600732
# Iteration 381, loss = 0.13588275
# Iteration 382, loss = 0.13587974
# Iteration 383, loss = 0.13586217
# Iteration 384, loss = 0.13574926
# Iteration 385, loss = 0.13576096
# Iteration 386, loss = 0.13564336
# Iteration 387, loss = 0.13559321
# Iteration 388, loss = 0.13557551
# Iteration 389, loss = 0.13549195
# Iteration 390, loss = 0.13551227
# Iteration 391, loss = 0.13531965
# Iteration 392, loss = 0.13538707
# Iteration 393, loss = 0.13525913
# Iteration 394, loss = 0.13525827
# Iteration 395, loss = 0.13510580
# Iteration 396, loss = 0.13502644
# Iteration 397, loss = 0.13500738
# Iteration 398, loss = 0.13491380
# Iteration 399, loss = 0.13489142
# Iteration 400, loss = 0.13479228
# Iteration 401, loss = 0.13484048
# Iteration 402, loss = 0.13469658
# Iteration 403, loss = 0.13468589
# Iteration 404, loss = 0.13452683
# Iteration 405, loss = 0.13441531
# Iteration 406, loss = 0.13443393
# Iteration 407, loss = 0.13444134
# Iteration 408, loss = 0.13441102
# Iteration 409, loss = 0.13430594
# Iteration 410, loss = 0.13413193
# Iteration 411, loss = 0.13416951
# Iteration 412, loss = 0.13434953
# Iteration 413, loss = 0.13406237
# Iteration 414, loss = 0.13393153
# Iteration 415, loss = 0.13404118
# Iteration 416, loss = 0.13392868
# Iteration 417, loss = 0.13384870
# Iteration 418, loss = 0.13373271
# Iteration 419, loss = 0.13378665
# Iteration 420, loss = 0.13369795
# Iteration 421, loss = 0.13359860
# Iteration 422, loss = 0.13352330
# Iteration 423, loss = 0.13346081
# Iteration 424, loss = 0.13337124
# Iteration 425, loss = 0.13335178
# Iteration 426, loss = 0.13338427
# Iteration 427, loss = 0.13328674
# Iteration 428, loss = 0.13318550
# Iteration 429, loss = 0.13314465
# Iteration 430, loss = 0.13307933
# Iteration 431, loss = 0.13312172
# Iteration 432, loss = 0.13293796
# Iteration 433, loss = 0.13300532
# Iteration 434, loss = 0.13274842
# Iteration 435, loss = 0.13289962
# Iteration 436, loss = 0.13279243
# Iteration 437, loss = 0.13274974
# Iteration 438, loss = 0.13272376
# Iteration 439, loss = 0.13262232
# Iteration 440, loss = 0.13256858
# Iteration 441, loss = 0.13259766
# Iteration 442, loss = 0.13240780
# Iteration 443, loss = 0.13246630
# Iteration 444, loss = 0.13239863
# Iteration 445, loss = 0.13240144
# Iteration 446, loss = 0.13223930
# Iteration 447, loss = 0.13234546
# Iteration 448, loss = 0.13212878
# Iteration 449, loss = 0.13210354
# Iteration 450, loss = 0.13203924
# Iteration 451, loss = 0.13201719
# Iteration 452, loss = 0.13192659
# Iteration 453, loss = 0.13186210
# Iteration 454, loss = 0.13191881
# Iteration 455, loss = 0.13187292
# Iteration 456, loss = 0.13174716
# Iteration 457, loss = 0.13165744
# Iteration 458, loss = 0.13159661
# Iteration 459, loss = 0.13161721
# Iteration 460, loss = 0.13157961
# Iteration 461, loss = 0.13142435
# Iteration 462, loss = 0.13145875
# Iteration 463, loss = 0.13139351
# Iteration 464, loss = 0.13133103
# Iteration 465, loss = 0.13128349
# Iteration 466, loss = 0.13127382
# Iteration 467, loss = 0.13121277
# Iteration 468, loss = 0.13108027
# Iteration 469, loss = 0.13119584
# Iteration 470, loss = 0.13108260
# Iteration 471, loss = 0.13109016
# Iteration 472, loss = 0.13091345
# Iteration 473, loss = 0.13089744
# Iteration 474, loss = 0.13084197
# Iteration 475, loss = 0.13081720
# Iteration 476, loss = 0.13076585
# Iteration 477, loss = 0.13080998
# Iteration 478, loss = 0.13068146
# Iteration 479, loss = 0.13068001
# Iteration 480, loss = 0.13051394
# Iteration 481, loss = 0.13051875
# Iteration 482, loss = 0.13053425
# Iteration 483, loss = 0.13041037
# Iteration 484, loss = 0.13046300
# Iteration 485, loss = 0.13045114
# Iteration 486, loss = 0.13028022
# Iteration 487, loss = 0.13020443
# Iteration 488, loss = 0.13019748
# Iteration 489, loss = 0.13013442
# Iteration 490, loss = 0.13008002
# Iteration 491, loss = 0.13011975
# Iteration 492, loss = 0.13010488
# Iteration 493, loss = 0.13000936
# Iteration 494, loss = 0.12993901
# Iteration 495, loss = 0.12982808
# Iteration 496, loss = 0.12979968
# Iteration 497, loss = 0.12989349
# Iteration 498, loss = 0.12974263
# Iteration 499, loss = 0.12970735
# Iteration 500, loss = 0.12979662
# Iteration 501, loss = 0.12962939
# Iteration 502, loss = 0.12963789
# Iteration 503, loss = 0.12947944
# Iteration 504, loss = 0.12952477
# Iteration 505, loss = 0.12948285
# Iteration 506, loss = 0.12933373
# Iteration 507, loss = 0.12930103
# Iteration 508, loss = 0.12934006
# Iteration 509, loss = 0.12933871
# Iteration 510, loss = 0.12928259
# Iteration 511, loss = 0.12923388
# Iteration 512, loss = 0.12922491
# Iteration 513, loss = 0.12904652
# Iteration 514, loss = 0.12903059
# Iteration 515, loss = 0.12900154
# Iteration 516, loss = 0.12895673
# Iteration 517, loss = 0.12904294
# Iteration 518, loss = 0.12886239
# Iteration 519, loss = 0.12882331
# Iteration 520, loss = 0.12881533
# Iteration 521, loss = 0.12879028
# Iteration 522, loss = 0.12871675
# Iteration 523, loss = 0.12867559
# Iteration 524, loss = 0.12873202
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
r_squared = fitted_mlp_r.score(x_scaled, y)
print(r_squared)

y_hat = fitted_mlp_r.predict(x_scaled)
errors = abs(y_hat - y)
plt.xlabel('error')
plt.ylabel('y')
plt.scatter(errors, y)
plt.show()
print('avg errors', errors.mean())
rsme = np.sqrt(((y_hat - y)**2).mean())
print('RMSE', rsme)
# Out:
# 0.8073409144875172
# avg errors 0.34642385637840456
# RMSE 0.506493102744384

# %%
r_squared = fitted_mlp_r.score(x, y)
print(r_squared)

y_hat = fitted_mlp_r.predict(x)
errors = abs(y_hat - y)
plt.xlabel('error')
plt.ylabel('y')
plt.scatter(errors, y)
plt.show()
print('avg errors', errors.mean())
rsme = np.sqrt(((y_hat - y)**2).mean())
print('RMSE', rsme)
# Out:
# 0.5986209683342416
# avg errors 0.5333008196653621
# RMSE 0.7310652296895852
